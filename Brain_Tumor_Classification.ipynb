# %% [markdown]
# # Brain Tumor MRI Dataset

# %% [markdown]
# This dataset contains 7023 images of human brain MRI images which are classified into 4 classes: glioma - meningioma - no tumor and pituitary.

# %% [markdown]
# ## Train the model

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing.image import ImageDataGenerator

from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile
local_zip = '/content/drive/MyDrive/classification_of_diseases/Brain_Tumor_dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
train_path = '/content/Training'
test_path = '/content/Testing'

# %%
class_names = {0: 'Glioma', 1: 'Meningioma', 2: 'Not Tumor', 3: 'Pituitary'}

batch_size = 32
epochs = 50
IMG_HEIGHT = 64
IMG_WIDTH = 64
IMG_COLOR = 3
num_of_classes = 4

# %%
values = [1321, 1339, 1595, 1457]
categories = ['Glioma', 'Meningioma', 'Not Tumor', 'Pituitary']

plt.bar(categories, values)

plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Training Images')

plt.show()

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', mode='min', restore_best_weights=True, patience=15, verbose=1)

# Checkpoints
checkpoint_filepath = '/content/drive/MyDrive/classification_of_diseases/brain_tumor_model.hdf5'

model_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, monitor='val_loss', mode='min', save_best_only=True, verbose=1)

# Scheduler
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=12, min_lr=1e-6)

# %%
rescale = 1./255

train_image_generator = ImageDataGenerator(rescale=rescale, 
                                           validation_split=0.2)

test_image_generator = ImageDataGenerator(rescale=rescale)

train_data_gen = train_image_generator.flow_from_directory(
        directory=train_path,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
        subset='training', seed=6)

val_data_gen = train_image_generator.flow_from_directory(
        directory=train_path,
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
        subset='validation', seed=6)

test_data_gen = test_image_generator.flow_from_directory(
        directory=test_path, 
        target_size=(IMG_HEIGHT, IMG_WIDTH),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 4571 images belonging to 4 classes.
# Found 1141 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
def plotImages(images_arr, labels_arr):
    fig, axes = plt.subplots(5, 10, figsize=(20, 12))

    for i in range(5):
        for j in range(10):
            img = images_arr[i * 5 + j]
            label = labels_arr[i * 5 + j]
            axes[i][j].imshow(img)
            #axes[i][j].axis('off')
            l = np.argmax(label)
            axes[i][j].set_title(class_names[l], fontsize=12)
    plt.show()

sample_training_images, sample_training_labels = next(train_data_gen)
plotImages(sample_training_images[:50], sample_training_labels[:50])

# %%
def plotAugmentedImages(images_arr):
    fig, axes = plt.subplots(len(images_arr), 1, figsize=(5,len(images_arr) * 3))

    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.show()

n = 5 # Choose an image
augmented_images = [train_data_gen[0][0][n] for i in range(5)]
plotAugmentedImages(augmented_images)

# %%
import seaborn as sns

def plot_diagrams(history, h=16, w=6):
    epochs = len(history.history['loss'])
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize=(h, w))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(64, (7, 7), activation='relu', padding='same', input_shape=(IMG_HEIGHT, IMG_WIDTH, IMG_COLOR)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(128, (7, 7), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Conv2D(256, (7, 7), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(num_of_classes, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_59 (Conv2D)          (None, 64, 64, 64)        9472
#
#  batch_normalization_55 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  max_pooling2d_59 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  conv2d_60 (Conv2D)          (None, 32, 32, 128)       401536
#
#  batch_normalization_56 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  max_pooling2d_60 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  conv2d_61 (Conv2D)          (None, 16, 16, 256)       1605888
#
#  batch_normalization_57 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  max_pooling2d_61 (MaxPoolin  (None, 8, 8, 256)        0
#  g2D)
#
#  flatten_19 (Flatten)        (None, 16384)             0
#
#  dropout_56 (Dropout)        (None, 16384)             0
#
#  dense_74 (Dense)            (None, 256)               4194560
#
#  dropout_57 (Dropout)        (None, 256)               0
#
#  dense_75 (Dense)            (None, 128)               32896
#
#  dropout_58 (Dropout)        (None, 128)               0
#
#  dense_76 (Dense)            (None, 64)                8256
#
#  dense_77 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 6,254,660
# Trainable params: 6,253,764
# Non-trainable params: 896
# _________________________________________________________________

# %%
history = model.fit(x=train_data_gen, 
                    validation_data=val_data_gen, 
                    epochs=epochs, batch_size=batch_size, shuffle=True, callbacks=[early_stopping, model_checkpoint, reduce_lr], verbose=1)
# Out:
# Epoch 1/50
# 143/143 [==============================] - ETA: 0s - loss: 1.1864 - accuracy: 0.6130
# Epoch 1: val_loss improved from inf to 2.00847, saving model to /content/drive/MyDrive/classification_of_diseases/brain_tumor_model.hdf5
# 143/143 [==============================] - 19s 110ms/step - loss: 1.1864 - accuracy: 0.6130 - val_loss: 2.0085 - val_accuracy: 0.2673 - lr: 0.0010
# Epoch 2/50
# 143/143 [==============================] - ETA: 0s - loss: 0.6797 - accuracy: 0.7241
# Epoch 2: val_loss did not improve from 2.00847
# 143/143 [==============================] - 15s 108ms/step - loss: 0.6797 - accuracy: 0.7241 - val_loss: 2.0679 - val_accuracy: 0.4417 - lr: 0.0010
# Epoch 3/50
# 143/143 [==============================] - ETA: 0s - loss: 0.5580 - accuracy: 0.8011
# Epoch 3: val_loss improved from 2.00847 to 1.03492, saving model to /content/drive/MyDrive/classification_of_diseases/brain_tumor_model.hdf5
# 143/143 [==============================] - 18s 127ms/step - loss: 0.5580 - accuracy: 0.8011 - val_loss: 1.0349 - val_accuracy: 0.6354 - lr: 0.0010
# Epoch 4/50
# 143/143 [==============================] - ETA: 0s - loss: 0.4668 - accuracy: 0.8280
# Epoch 4: val_loss did not improve from 1.03492
# 143/143 [==============================] - 15s 108ms/step - loss: 0.4668 - accuracy: 0.8280 - val_loss: 3.4465 - val_accuracy: 0.4926 - lr: 0.0010
# Epoch 5/50
# 143/143 [==============================] - ETA: 0s - loss: 0.3871 - accuracy: 0.8567
# Epoch 5: val_loss improved from 1.03492 to 0.88559, saving model to /content/drive/MyDrive/classification_of_diseases/brain_tumor_model.hdf5
# 143/143 [==============================] - 18s 126ms/step - loss: 0.3871 - accuracy: 0.8567 - val_loss: 0.8856 - val_accuracy: 0.7599 - lr: 0.0010
# Epoch 6/50
# 143/143 [==============================] - ETA: 0s - loss: 0.3412 - accuracy: 0.8764
# Epoch 6: val_loss did not improve from 0.88559
# 143/143 [==============================] - 15s 107ms/step - loss: 0.3412 - accuracy: 0.8764 - val_loss: 2.7284 - val_accuracy: 0.4969 - lr: 0.0010
# Epoch 7/50
# 143/143 [==============================] - ETA: 0s - loss: 0.2787 - accuracy: 0.8928
# Epoch 7: val_loss did not improve from 0.88559
# 143/143 [==============================] - 15s 106ms/step - loss: 0.2787 - accuracy: 0.8928 - val_loss: 6.1248 - val_accuracy: 0.4645 - lr: 0.0010
# Epoch 8/50
# 143/143 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.9099
# Epoch 8: val_loss did not improve from 0.88559
# 143/143 [==============================] - 15s 105ms/step - loss: 0.2565 - accuracy: 0.9099 - val_loss: 0.9053 - val_accuracy: 0.7467 - lr: 0.0010
# Epoch 9/50
# 143/143 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.9166
# Epoch 9: val_loss did not improve from 0.88559
# 143/143 [==============================] - 15s 105ms/step - loss: 0.2338 - accuracy: 0.9166 - val_loss: 2.1788 - val_accuracy: 0.6240 - lr: 0.0010
# Epoch 10/50
# 143/143 [==============================] - ETA: 0s - loss: 0.1983 - accuracy: 0.9324
# Epoch 10: val_loss did not improve from 0.88559
# 143/143 [==============================] - 17s 119ms/step - loss: 0.1983 - accuracy: 0.9324 - val_loss: 0.9794 - val_accuracy: 0.7528 - lr: 0.0010
# Epoch 11/50
# 143/143 [==============================] - ETA: 0s - loss: 0.1825 - accuracy: 0.9320
# Epoch 11: val_loss improved from 0.88559 to 0.70166, saving model to /content/drive/MyDrive/classification_of_diseases/brain_tumor_model.hdf5
# 143/143 [==============================] - 16s 113ms/step - loss: 0.1825 - accuracy: 0.9320 - val_loss: 0.7017 - val_accuracy: 0.7791 - lr: 0.0010
# Epoch 12/50
# 143/143 [==============================] - ETA: 0s - loss: 0.1741 - accuracy: 0.9370
# Epoch 12: val_loss did not improve from 0.70166
# 143/143 [==============================] - 17s 118ms/step - loss: 0.1741 - accuracy: 0.9370 - val_loss: 0.9103 - val_accuracy: 0.7677 - lr: 0.0010
# Epoch 13/50
# 143/143 [==============================] - ETA: 0s - loss: 0.1283 - accuracy: 0.9547
# Epoch 13: val_loss improved from 0.70166 to 0.66438, saving model to /content/drive/MyDrive/classification_of_diseases/brain_tumor_model.hdf5
# 143/143 [==============================] - 16s 113ms/step - loss: 0.1283 - accuracy: 0.9547 - val_loss: 0.6644 - val_accuracy: 0.8317 - lr: 0.0010
# Epoch 14/50
# 143/143 [==============================] - ETA: 0s - loss: 0.1172 - accuracy: 0.9565
# Epoch 14: val_loss did not improve from 0.66438
# 143/143 [==============================] - 16s 109ms/step - loss: 0.1172 - accuracy: 0.9565 - val_loss: 1.0143 - val_accuracy: 0.7169 - lr: 0.0010
# Epoch 15/50
# 143/143 [==============================] - ETA: 0s - loss: 0.1125 - accuracy: 0.9589
# Epoch 15: val_loss improved from 0.66438 to 0.54875, saving model to /content/drive/MyDrive/classification_of_diseases/brain_tumor_model.hdf5
# 143/143 [==============================] - 16s 114ms/step - loss: 0.1125 - accuracy: 0.9589 - val_loss: 0.5488 - val_accuracy: 0.8712 - lr: 0.0010
# Epoch 16/50
# 143/143 [==============================] - ETA: 0s - loss: 0.1235 - accuracy: 0.9562
# Epoch 16: val_loss did not improve from 0.54875
# 143/143 [==============================] - 17s 121ms/step - loss: 0.1235 - accuracy: 0.9562 - val_loss: 2.4356 - val_accuracy: 0.5837 - lr: 0.0010
# Epoch 17/50
# 143/143 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9626
# Epoch 17: val_loss improved from 0.54875 to 0.44846, saving model to /content/drive/MyDrive/classification_of_diseases/brain_tumor_model.hdf5
# 143/143 [==============================] - 16s 113ms/step - loss: 0.1027 - accuracy: 0.9626 - val_loss: 0.4485 - val_accuracy: 0.8843 - lr: 0.0010
# Epoch 18/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 0.9731
# Epoch 18: val_loss did not improve from 0.44846
# 143/143 [==============================] - 15s 108ms/step - loss: 0.0868 - accuracy: 0.9731 - val_loss: 0.5097 - val_accuracy: 0.8528 - lr: 0.0010
# Epoch 19/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0892 - accuracy: 0.9687
# Epoch 19: val_loss did not improve from 0.44846
# 143/143 [==============================] - 15s 105ms/step - loss: 0.0892 - accuracy: 0.9687 - val_loss: 2.6031 - val_accuracy: 0.6126 - lr: 0.0010
# Epoch 20/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.9731
# Epoch 20: val_loss improved from 0.44846 to 0.37163, saving model to /content/drive/MyDrive/classification_of_diseases/brain_tumor_model.hdf5
# 143/143 [==============================] - 16s 114ms/step - loss: 0.0797 - accuracy: 0.9731 - val_loss: 0.3716 - val_accuracy: 0.9036 - lr: 0.0010
# Epoch 21/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9818
# Epoch 21: val_loss did not improve from 0.37163
# 143/143 [==============================] - 17s 121ms/step - loss: 0.0511 - accuracy: 0.9818 - val_loss: 0.6416 - val_accuracy: 0.8528 - lr: 0.0010
# Epoch 22/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9783
# Epoch 22: val_loss did not improve from 0.37163
# 143/143 [==============================] - 15s 107ms/step - loss: 0.0753 - accuracy: 0.9783 - val_loss: 0.5611 - val_accuracy: 0.8712 - lr: 0.0010
# Epoch 23/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0474 - accuracy: 0.9851
# Epoch 23: val_loss did not improve from 0.37163
# 143/143 [==============================] - 17s 118ms/step - loss: 0.0474 - accuracy: 0.9851 - val_loss: 0.5650 - val_accuracy: 0.8931 - lr: 0.0010
# Epoch 24/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9864
# Epoch 24: val_loss did not improve from 0.37163
# 143/143 [==============================] - 15s 107ms/step - loss: 0.0434 - accuracy: 0.9864 - val_loss: 0.7508 - val_accuracy: 0.8554 - lr: 0.0010
# Epoch 25/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9814
# Epoch 25: val_loss did not improve from 0.37163
# 143/143 [==============================] - 16s 113ms/step - loss: 0.0707 - accuracy: 0.9814 - val_loss: 0.6143 - val_accuracy: 0.8738 - lr: 0.0010
# Epoch 26/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0399 - accuracy: 0.9862
# Epoch 26: val_loss did not improve from 0.37163
# 143/143 [==============================] - 15s 107ms/step - loss: 0.0399 - accuracy: 0.9862 - val_loss: 0.7907 - val_accuracy: 0.8326 - lr: 0.0010
# Epoch 27/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9862
# Epoch 27: val_loss did not improve from 0.37163
# 143/143 [==============================] - 15s 106ms/step - loss: 0.0382 - accuracy: 0.9862 - val_loss: 0.6312 - val_accuracy: 0.8624 - lr: 0.0010
# Epoch 28/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0552 - accuracy: 0.9840
# Epoch 28: val_loss did not improve from 0.37163
# 143/143 [==============================] - 15s 106ms/step - loss: 0.0552 - accuracy: 0.9840 - val_loss: 1.0756 - val_accuracy: 0.7572 - lr: 0.0010
# Epoch 29/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0557 - accuracy: 0.9823
# Epoch 29: val_loss did not improve from 0.37163
# 143/143 [==============================] - 17s 121ms/step - loss: 0.0557 - accuracy: 0.9823 - val_loss: 0.5026 - val_accuracy: 0.9045 - lr: 0.0010
# Epoch 30/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9886
# Epoch 30: val_loss did not improve from 0.37163
# 143/143 [==============================] - 15s 106ms/step - loss: 0.0380 - accuracy: 0.9886 - val_loss: 0.7141 - val_accuracy: 0.8826 - lr: 0.0010
# Epoch 31/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0667 - accuracy: 0.9816
# Epoch 31: val_loss did not improve from 0.37163
# 143/143 [==============================] - 15s 106ms/step - loss: 0.0667 - accuracy: 0.9816 - val_loss: 0.6214 - val_accuracy: 0.8650 - lr: 0.0010
# Epoch 32/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0595 - accuracy: 0.9799
# Epoch 32: val_loss did not improve from 0.37163
# 143/143 [==============================] - 15s 106ms/step - loss: 0.0595 - accuracy: 0.9799 - val_loss: 0.7403 - val_accuracy: 0.7844 - lr: 0.0010
# Epoch 33/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9954
# Epoch 33: val_loss did not improve from 0.37163
# 143/143 [==============================] - 15s 106ms/step - loss: 0.0175 - accuracy: 0.9954 - val_loss: 0.6563 - val_accuracy: 0.8808 - lr: 5.0000e-04
# Epoch 34/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9961
# Epoch 34: val_loss did not improve from 0.37163
# 143/143 [==============================] - 15s 106ms/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 0.5560 - val_accuracy: 0.8975 - lr: 5.0000e-04
# Epoch 35/50
# 143/143 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9976Restoring model weights from the end of the best epoch: 20.
#
# Epoch 35: val_loss did not improve from 0.37163
# 143/143 [==============================] - 15s 106ms/step - loss: 0.0091 - accuracy: 0.9976 - val_loss: 0.6963 - val_accuracy: 0.9018 - lr: 5.0000e-04
# Epoch 35: early stopping

# %%
train_loss, train_acc = model.evaluate(train_data_gen, verbose=2)
print("Train accuracy: " + "{:.2f}".format(train_acc*100) + "%")
# Out:
# 143/143 - 10s - loss: 0.0409 - accuracy: 0.9884 - 10s/epoch - 72ms/step
# Train accuracy: 98.84%

# %% [markdown]
# ## Evaluate the model

# %%
test_loss, test_acc = model.evaluate(test_data_gen, verbose=2)
print("Test accuracy: " + "{:.2f}".format(test_acc*100) + "%")
# Out:
# 41/41 - 4s - loss: 0.1869 - accuracy: 0.9413 - 4s/epoch - 90ms/step
# Test accuracy: 94.13%

# %%
plot_diagrams(history)

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_test, y_pred, h=8, w=5):
    fig, ax = plt.subplots(figsize=(h, w))
    #Get the confusion matrix
    cf_matrix = confusion_matrix(y_test, y_pred)
    ax = sns.heatmap(cf_matrix, annot=True, cmap='Reds', fmt='d')

    ax.set_title('Seaborn Confusion Matrix with labels\n\n');
    ax.set_xlabel('\nPredicted Category')
    ax.set_ylabel('Actual Category ');

    ## Ticket labels - List must be in alphabetical order
    ax.xaxis.set_ticklabels(['Glioma', 'Meningioma', 'Not Tumor', 'Pituitary'])
    ax.yaxis.set_ticklabels(['Glioma', 'Meningioma', 'Not Tumor', 'Pituitary'])

    ## Display the visualization of the Confusion Matrix.
    plt.show()

predicted_labels = model.predict(test_data_gen)
predicted_classes = np.argmax(predicted_labels, axis=1)
y_test = np.array(test_data_gen.labels)
plot_confusion_matrix(y_test, predicted_classes)
# Out:
# 41/41 [==============================] - 3s 60ms/step

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test, predicted_classes)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95       300
#            1       0.96      0.78      0.86       306
#            2       0.92      1.00      0.96       405
#            3       0.97      1.00      0.99       300
#
#     accuracy                           0.94      1311
#    macro avg       0.94      0.94      0.94      1311
# weighted avg       0.94      0.94      0.94      1311

# %% [markdown]
# ## Load the model

# %%
from keras.models import load_model
best_model = load_model(checkpoint_filepath)

# %%
best_model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_59 (Conv2D)          (None, 64, 64, 64)        9472
#
#  batch_normalization_55 (Bat  (None, 64, 64, 64)       256
#  chNormalization)
#
#  max_pooling2d_59 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  conv2d_60 (Conv2D)          (None, 32, 32, 128)       401536
#
#  batch_normalization_56 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  max_pooling2d_60 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  conv2d_61 (Conv2D)          (None, 16, 16, 256)       1605888
#
#  batch_normalization_57 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  max_pooling2d_61 (MaxPoolin  (None, 8, 8, 256)        0
#  g2D)
#
#  flatten_19 (Flatten)        (None, 16384)             0
#
#  dropout_56 (Dropout)        (None, 16384)             0
#
#  dense_74 (Dense)            (None, 256)               4194560
#
#  dropout_57 (Dropout)        (None, 256)               0
#
#  dense_75 (Dense)            (None, 128)               32896
#
#  dropout_58 (Dropout)        (None, 128)               0
#
#  dense_76 (Dense)            (None, 64)                8256
#
#  dense_77 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 6,254,660
# Trainable params: 6,253,764
# Non-trainable params: 896
# _________________________________________________________________

# %%
from keras.utils.layer_utils import count_params

trainable_params = count_params(best_model.trainable_weights)
non_trainable_params = count_params(best_model.non_trainable_weights)
print("Trainable params:", trainable_params)
print("Non trainable params:", non_trainable_params)
# Out:
# Trainable params: 6253764
# Non trainable params: 896

# %%
train_loss, train_acc = best_model.evaluate(train_data_gen, verbose=2)
print("Train accuracy: " + "{:.2f}".format(train_acc*100) + "%")
# Out:
# 143/143 - 11s - loss: 0.0409 - accuracy: 0.9884 - 11s/epoch - 75ms/step
# Train accuracy: 98.84%

# %%
test_loss, test_acc = best_model.evaluate(test_data_gen, verbose=2)
print("Test accuracy: " + "{:.2f}".format(test_acc*100) + "%")
# Out:
# 41/41 - 2s - loss: 0.1869 - accuracy: 0.9413 - 2s/epoch - 59ms/step
# Test accuracy: 94.13%
